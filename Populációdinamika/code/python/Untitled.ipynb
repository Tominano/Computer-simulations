# %%
# %pylab inline
from scipy.optimize import curve_fit
from scipy import stats
import pandas as pd
from scipy.interpolate import interp1d
from scipy.signal import argrelextrema
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
date_1 = loadtxt("e011.data") #3omega
date_2 = loadtxt("e021.data") #3omega
date_3 = loadtxt("e031.data") #3omega
date_4 = loadtxt("e051.data") #3omega
date_5 = loadtxt("e081.data") #3omega
date_6 = loadtxt("e11.data") #3omega


datr_1 = loadtxt("r011.data") #3omega
datr_2 = loadtxt("r021.data") #3omega
datr_3 = loadtxt("r031.data") #3omega
datr_4 = loadtxt("r051.data") #3omega
datr_5 = loadtxt("r081.data") #3omega
datr_6 = loadtxt("r11.data") #3omega


date_11 = loadtxt("e0105.data") #3omega
date_21 = loadtxt("e0205.data") #3omega
date_31 = loadtxt("e0305.data") #3omega
date_41 = loadtxt("e0505.data") #3omega
date_51 = loadtxt("e0805.data") #3omega
date_61 = loadtxt("e105.data") #3omega


datr_11 = loadtxt("r0105.data") #3omega
datr_21 = loadtxt("r0205.data") #3omega
datr_31 = loadtxt("r0305.data") #3omega
datr_41 = loadtxt("r0505.data") #3omega
datr_51 = loadtxt("r0805.data") #3omega
datr_61 = loadtxt("r105.data") #3omega

# %%
date_111 = loadtxt("e010.data") #3omega
date_211 = loadtxt("e020.data") #3omega
date_311 = loadtxt("e030.data") #3omega
date_411 = loadtxt("e050.data") #3omega
date_511 = loadtxt("e080.data") #3omega
date_611 = loadtxt("e10.data") #3omega


datr_111 = loadtxt("r010.data") #3omega
datr_211 = loadtxt("r020.data") #3omega
datr_311 = loadtxt("r030.data") #3omega
datr_411 = loadtxt("r050.data") #3omega
datr_511 = loadtxt("r080.data") #3omega
datr_611 = loadtxt("r10.data") #3omega

# %%
date_1111 = loadtxt("e01_1.data") #3omega
date_2111= loadtxt("e02_1.data") #3omega
date_3111 = loadtxt("e03_1.data") #3omega
date_4111 = loadtxt("e05_1.data") #3omega
date_5111 = loadtxt("e08_1.data") #3omega
date_6111 = loadtxt("e1_1.data") #3omega


datr_1111 = loadtxt("r0.1_1.data") #3omega
datr_2111 = loadtxt("r0.2_1.data") #3omega
datr_3111= loadtxt("r0.3_1.data") #3omega
datr_4111 = loadtxt("r0.5_1.data") #3omega
datr_5111 = loadtxt("r0.8_1.data") #3omega
datr_6111 = loadtxt("r1_1.data") #3omega

# %%
date_11111 = loadtxt("e01_05.data") #3omega
date_21111= loadtxt("e02_05.data") #3omega
date_31111 = loadtxt("e03_05.data") #3omega
date_41111 = loadtxt("e05_05.data") #3omega
date_51111 = loadtxt("e08_05.data") #3omega
date_61111 = loadtxt("e1_05.data") #3omega


datr_11111 = loadtxt("r01_05.data") #3omega
datr_21111 = loadtxt("r02_05.data") #3omega
datr_31111= loadtxt("r03_05.data") #3omega
datr_41111 = loadtxt("r05_05.data") #3omega
datr_51111 = loadtxt("r08_05.data") #3omega
datr_61111 = loadtxt("r1_05.data") #3omega

# %%
y1 = ([])
for t in arange(0,20,0.05):
    y1.append(1/(1+((1/0.1)-1)*exp(-(-0.5*t))))

# %%
y2 = ([])    
for t in arange(0,20,0.05):
    y2.append(1/(1+((1/0.2)-1)*exp(-(-0.5*t))))

# %%
y3 = ([])
for t in arange(0,20,0.05):
    y3.append(1/(1+((1/0.3)-1)*exp(-(-0.5*t))))

# %%
y4 = ([])
for t in arange(0,20,0.05):
    y4.append(1/(1+((1/0.5)-1)*exp(-(-0.5*t))))

# %%
y5 = ([])
for t in arange(0,20,0.05):
    y5.append(1/(1+((1/0.8)-1)*exp(-(-0.5*t))))

# %%
y6 = ([])
for t in arange(0,20,0.05):
    y6.append(1/(1+((1/1)-1)*exp(-(-0.5*t))))

# %%
y = ([])  

for t in arange(0,20,0.05):
    y.append(t)

# %%
len(y2)

# %%
figure(num=None, figsize=(10, 10), dpi=160, facecolor='w', edgecolor='r')  

title("r = 1", fontsize = 30)
plot(date_1[:,0],date_1[:,1],color = 'r', label = "Euler, dt = 0.05")
plot(date_2[:,0],date_2[:,1],color = 'r')
plot(date_3[:,0],date_3[:,1],color = 'r')
plot(date_4[:,0],date_4[:,1],color = 'r')
plot(date_5[:,0],date_5[:,1],color = 'r')
plot(date_6[:,0],date_6[:,1],color = 'r')
plot(y,y1,'--', markersize = '0.6', color = 'b', label = "Elméleti")
plot(y,y2,'--', markersize = '0.6',color = 'b')
plot(y,y3,'--', markersize = '0.6',color = 'b')
plot(y,y4,'--', markersize = '0.6',color = 'b')
plot(y,y5,'--', markersize = '0.6',color = 'b')
plot(y,y6,'--', markersize = '0.6',color = 'b')

plot(datr_1[:,0],datr_1[:,1],'x',color = 'g', label = "RK4")
plot(datr_2[:,0],datr_2[:,1],'x',color = 'g')
plot(datr_3[:,0],datr_3[:,1],'x',color = 'g')
plot(datr_4[:,0],datr_4[:,1],'x',color = 'g')
plot(datr_5[:,0],datr_5[:,1],'x',color = 'g')
plot(datr_6[:,0],datr_6[:,1],'x',color = 'g')


#plot(date_7[:,0],date_7[:,1], label = "proba")
#plot(date_8[:,0],date_8[:,1], label = "proba")
xlim(0,10)
xlabel('Idő', fontsize = 30)
ylabel('Telítettség', fontsize = 30)
legend(loc='lower right',fontsize=20)
grid(True)
#savefig('r1.png')

# %%
figure(num=None, figsize=(10, 10), dpi=160, facecolor='w', edgecolor='r')  

title("r = 0.5", fontsize = 30)
plot(date_11[:,0],date_11[:,1],color = 'r', label = "Euler, dt = 0.05")
plot(date_21[:,0],date_21[:,1],color = 'r')
plot(date_31[:,0],date_31[:,1],color = 'r')
plot(date_41[:,0],date_41[:,1],color = 'r')
plot(date_51[:,0],date_51[:,1],color = 'r')
plot(date_61[:,0],date_61[:,1],color = 'r')
plot(y,y1,'--', markersize = '0.6', color = 'b', label = "Elméleti")
plot(y,y2,'--', markersize = '0.6',color = 'b')
plot(y,y3,'--', markersize = '0.6',color = 'b')
plot(y,y4,'--', markersize = '0.6',color = 'b')
plot(y,y5,'--', markersize = '0.6',color = 'b')
plot(y,y6,'--', markersize = '0.6',color = 'b')

plot(datr_11[:,0],datr_11[:,1],'x',color = 'g', label = "RK4")
plot(datr_21[:,0],datr_21[:,1],'x',color = 'g')
plot(datr_31[:,0],datr_31[:,1],'x',color = 'g')
plot(datr_41[:,0],datr_41[:,1],'x',color = 'g')
plot(datr_51[:,0],datr_51[:,1],'x',color = 'g')
plot(datr_61[:,0],datr_61[:,1],'x',color = 'g')


xlim(0,10)
xlabel('Idő', fontsize = 30)
ylabel('Telítettség', fontsize = 30)
legend(loc='lower right',fontsize=20)
grid(True)
#savefig('r05.png')

# %%
figure(num=None, figsize=(10, 10), dpi=160, facecolor='w', edgecolor='r')  

title("r = 0", fontsize = 30)
plot(date_111[:,0],date_111[:,1],color = 'r', label = "Euler, dt = 0.05")
plot(date_211[:,0],date_211[:,1],color = 'r')
plot(date_311[:,0],date_311[:,1],color = 'r')
plot(date_411[:,0],date_411[:,1],color = 'r')
plot(date_511[:,0],date_511[:,1],color = 'r')
plot(date_611[:,0],date_611[:,1],color = 'r')
plot(y,y1,'--', markersize = '0.6', color = 'b', label = "Elméleti")
plot(y,y2,'--', markersize = '0.6',color = 'b')
plot(y,y3,'--', markersize = '0.6',color = 'b')
plot(y,y4,'--', markersize = '0.6',color = 'b')
plot(y,y5,'--', markersize = '0.6',color = 'b')
plot(y,y6,'--', markersize = '0.6',color = 'b')

plot(datr_111[:,0],datr_111[:,1],'x',color = 'g', label = "RK4")
plot(datr_211[:,0],datr_211[:,1],'x',color = 'g')
plot(datr_311[:,0],datr_311[:,1],'x',color = 'g')
plot(datr_411[:,0],datr_411[:,1],'x',color = 'g')
plot(datr_511[:,0],datr_511[:,1],'x',color = 'g')
plot(datr_611[:,0],datr_611[:,1],'x',color = 'g')


xlim(0,10)
xlabel('Idő', fontsize = 30)
ylabel('Telítettség', fontsize = 30)
legend(loc='lower right',fontsize=20)
grid(True)
#savefig('r0.png')

# %%
figure(num=None, figsize=(10, 10), dpi=160, facecolor='w', edgecolor='r')  

title("r = -1", fontsize = 30)
plot(date_1111[:,0],date_1111[:,1],color = 'r', label = "Euler, dt = 0.05")
plot(date_2111[:,0],date_2111[:,1],color = 'r')
plot(date_3111[:,0],date_3111[:,1],color = 'r')
plot(date_4111[:,0],date_4111[:,1],color = 'r')
plot(date_5111[:,0],date_5111[:,1],color = 'r')
plot(date_6111[:,0],date_6111[:,1],color = 'r')
plot(y,y1,'--', markersize = '0.6', color = 'b', label = "Elméleti")
plot(y,y2,'--', markersize = '0.6',color = 'b')
plot(y,y3,'--', markersize = '0.6',color = 'b')
plot(y,y4,'--', markersize = '0.6',color = 'b')
plot(y,y5,'--', markersize = '0.6',color = 'b')
plot(y,y6,'--', markersize = '0.6',color = 'b')

plot(datr_1111[:,0],datr_1111[:,1],'x',color = 'g', label = "RK4")
plot(datr_2111[:,0],datr_2111[:,1],'x',color = 'g')
plot(datr_3111[:,0],datr_3111[:,1],'x',color = 'g')
plot(datr_4111[:,0],datr_4111[:,1],'x',color = 'g')
plot(datr_5111[:,0],datr_5111[:,1],'x',color = 'g')
plot(datr_6111[:,0],datr_6111[:,1],'x',color = 'g')


xlim(0,10)
xlabel('Idő', fontsize = 30)
ylabel('Telítettség', fontsize = 30)
legend(loc='lower right',fontsize=20)
grid(True)
#savefig('r_1.png')

# %%
figure(num=None, figsize=(10, 10), dpi=160, facecolor='w', edgecolor='r')  

title("r = -0.5", fontsize = 30)
plot(date_11111[:,0],date_11111[:,1],color = 'r', label = "Euler, dt = 0.05")
plot(date_21111[:,0],date_21111[:,1],color = 'r')
plot(date_31111[:,0],date_31111[:,1],color = 'r')
plot(date_41111[:,0],date_41111[:,1],color = 'r')
plot(date_51111[:,0],date_51111[:,1],color = 'r')
plot(date_61111[:,0],date_61111[:,1],color = 'r')
plot(y,y1,'--', markersize = '0.6', color = 'b', label = "Elméleti")
plot(y,y2,'--', markersize = '0.6',color = 'b')
plot(y,y3,'--', markersize = '0.6',color = 'b')
plot(y,y4,'--', markersize = '0.6',color = 'b')
plot(y,y5,'--', markersize = '0.6',color = 'b')
plot(y,y6,'--', markersize = '0.6',color = 'b')

plot(datr_11111[:,0],datr_11111[:,1],'x',color = 'g', label = "RK4")
plot(datr_21111[:,0],datr_21111[:,1],'x',color = 'g')
plot(datr_31111[:,0],datr_31111[:,1],'x',color = 'g')
plot(datr_41111[:,0],datr_41111[:,1],'x',color = 'g')
plot(datr_51111[:,0],datr_51111[:,1],'x',color = 'g')
plot(datr_61111[:,0],datr_61111[:,1],'x',color = 'g')


#xlim(0,10)
xlabel('Idő', fontsize = 30)
ylabel('Telítettség', fontsize = 30)
legend(loc='lower right',fontsize=20)
grid(True)
#savefig('r_05.png')

# %%
dat2_1 = loadtxt("1_1_120_80_1_1.data")

# %%
figure(num=None, figsize=(10, 10), dpi=160, facecolor='w', edgecolor='r')  

title(r"Kompetitív kizárás, $r_1$ = $r_2$ = 1, $\alpha$ = $\beta$ = 1", fontsize = 25)
plot(dat2_1[:,0],dat2_1[:,1],color = 'r', label = "Rókák, n(t=0)=100")
plot(dat2_1[:,0],dat2_1[:,2],color = 'b',label = "Nyulak, n(t=0)=90")



#xlim(0,10)
xlabel('Idő', fontsize = 30)
ylabel('Populáció száma n(t)', fontsize = 30)
legend(loc='center right',fontsize=20)
grid(True)
savefig('r1=r2=a=b.png')

# %%
dat2_2 = loadtxt("1_1_100_90_07_08.data")

# %%
figure(num=None, figsize=(10, 10), dpi=160, facecolor='w', edgecolor='r')  

title(r"Együttélés, $r_1$ = $r_2$ = 1, $\alpha$ = 0.7, $\beta$ = 0.8", fontsize = 25)
plot(dat2_2[:,0],dat2_2[:,1],color = 'r', label = "Rókák, n(t=0)=100")
plot(dat2_2[:,0],dat2_2[:,2],color = 'b',label = "Nyulak, n(t=0)=100")



#xlim(0,10)
xlabel('Idő', fontsize = 30)
ylabel('Populáció száma n(t)', fontsize = 30)
legend(loc='upper right',fontsize=20)
grid(True)
savefig('r1=r2=a=07b=08.png')

# %%
dat3_1 = loadtxt("elso.data")

# %%
figure(num=None, figsize=(10, 10), dpi=160, facecolor='w', edgecolor='r')  

title(r"a = 0.4, b,c = 0.003, d = 0.9, K =700", fontsize = 25)
plot(dat3_1[:,1],dat3_1[:,2])
#plot(dat3_1[:,0],dat3_1[:,2],color = 'b',label = "Nyulak")



#xlim(0,1500)
#ylim(0,1200)
xlabel('Nyulak', fontsize = 30)
ylabel('Rókák', fontsize = 30)
legend(loc='upper right',fontsize=20)
grid(True)
savefig('uccso.png')
# Out:
# No handles with labels found to put in legend.
