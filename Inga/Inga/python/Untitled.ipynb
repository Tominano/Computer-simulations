# %%
# %pylab inline 
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Enter linear or nonlinear: linear
# Length of pendulum L: 12
# Enter damping coefficient q: 0
# Enter driving frequencey Omega_D: 0
# Enter driving amplitude F_D: 0
# Enter theta(0) and omega(0): 0.2
dat_math_rk = loadtxt("pendulum_math_rk.data")

# %% [markdown]
# Runge-Kutta

# %%
figure(figsize = (10,5))
title("Matematikai inga kitérés-idő digramja", fontsize = 20)
plot(dat_math_rk[:,0],dat_math_rk[:,1], label = "mathetatical pendulum")#3
xlabel('Idő [s]', fontsize = 20)
ylabel('Kitérét $[rad]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

# %%
figure(figsize = (10,5))
title("Matematikai inga sebesség-idő digramja", fontsize = 20)
plot(dat_math_rk[:,0],dat_math_rk[:,2], label = "mathetatical pendulum")#3
xlabel('Idő [s]', fontsize = 20)
ylabel('Sebesség $[1/s]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

# %%
figure(figsize = (8,8))
title("Matematikai inga fázis digramja", fontsize = 20)
plot(dat_math_rk[:,1],dat_math_rk[:,2], label = "mathetatical pendulum")#3
xlabel('Kitérés $[rad]$', fontsize = 20)
ylabel('Szögsebesség $[1/s]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

# %%
figure(figsize = (10,5))
title("Matematikai inga ENERDZSI", fontsize = 20)
plot(dat_math_rk[:,0],dat_math_rk[:,3], label = "mathetatical pendulum")#3
xlabel('Kitérés $[rad]$', fontsize = 20)
ylabel('Szögsebesség $[1/s]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)
