# %%
# %pylab inline 
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Enter linear or nonlinear: linear
# Length of pendulum L: 12
# Enter damping coefficient q: 0
# Enter driving frequencey Omega_D: 0

# Enter driving amplitude F_D: 0
# Enter theta(0) and omega(0): 0.2
dat_math_rk = loadtxt("pendulum_math_rk_adapt.data") 
dat_math_rk_sim = loadtxt("pendulum_math_rk.data")

dat_csill_rk = loadtxt("pendulum_csill_rk_adapt.data") 
dat_csill_rk_sim = loadtxt("pendulum_csill_rk.data")
dat_ger_rk = loadtxt("pendulum_gerjesztett_rk_adapt.data") 
dat_ger_rk_sim = loadtxt("pendulum_gerjesztett_rk.data")
dat_ger_csill_rk = loadtxt("pendulum_ger_csill_rk_adapt.data") 
dat_ger_csill_rk_sim = loadtxt("pendulum_ger_csill_rk.data")


dat_EC_ger_csill = loadtxt("pendulum_EC_ger_csill.data")
dat_EC_gerjesztett = loadtxt("pendulum_EC_gerjesztett.data") 
dat_EC_mat = loadtxt("pendulum_EC_mat.data")
dat_EC_csill = loadtxt("pendulum_EC_csill.data")

dat_E_csill = loadtxt("pendulum_E_csill.data")
dat_E_ger_csill = loadtxt("pendulum_E_ger_csill.data") 
dat_E_gerjesztett = loadtxt("pendulum_E_gerjesztett.data")
dat_E_mat = loadtxt("pendulum_E_mat.data")

dat = loadtxt("pendulum.data")

# %%
figure(figsize = (15,10))
title("Matematikai inga kitérés-idő digramja", fontsize = 20)
plot(dat_math_rk[:,0],dat_math_rk[:,1], label = "Adaptiv Runge Kutta")#3
plot(dat_math_rk_sim[:,0],dat_math_rk_sim[:,1], label = "Runge Kutta")#3

plot(dat_E_mat[:,0],dat_E_mat[:,1], label = "Euler")#3
plot(dat_EC_mat[:,0],dat_EC_mat[:,1], label = "EulerCromer")

xlabel('Idő [s]', fontsize = 20)
ylabel('Kitérét $[rad]$', fontsize = 20)
legend(loc='lower left',fontsize=15)
grid(True)

savefig('mat_xt.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-343fba9b6ad3> in <module>
#       1 figure(figsize = (15,10))
#       2 title("Matematikai inga kitérés-idő digramja", fontsize = 20)
# ----> 3 plot(dat_math_rk[:,0],dat_math_rk[:,1], label = "Adaptiv Runge Kutta")#3
#       4 plot(dat_math_rk_sim[:,0],dat_math_rk_sim[:,1], label = "Runge Kutta")#3
#       5
#
# NameError: name 'dat_math_rk' is not defined

# %%
figure(figsize = (15,10))
title("Csillapított inga kitérés-idő digramja", fontsize = 20)
plot(dat_csill_rk[:,0],dat_csill_rk[:,1], label = "Adaptiv Runge Kutta")#3
plot(dat_csill_rk_sim[:,0],dat_csill_rk_sim[:,1], label = "Runge Kutta")#3

plot(dat_E_csill[:,0],dat_E_csill[:,1], label = "Euler")#3
plot(dat_EC_csill[:,0],dat_EC_csill[:,1], label = "EulerCromer")

xlim(0,30)
xlabel('Idő [s]', fontsize = 20)
ylabel('Kitérét $[rad]$', fontsize = 20)
legend(loc='upper right',fontsize=15)
grid(True)

savefig('csill_xt.png')

# %%
figure(figsize = (15,10))
title("Gerjesztett inga kitérés-idő digramja", fontsize = 20)
plot(dat_ger_rk[:,0],dat_ger_rk[:,1], label = "Adaptiv Runge Kutta")#3
plot(dat_ger_rk_sim[:,0],dat_ger_rk_sim[:,1], label = "Runge Kutta")#3

plot(dat_EC_gerjesztett[:,0],dat_EC_gerjesztett[:,1], label = "Euler-Cromer")#3
plot(dat_E_gerjesztett[:,0],dat_E_gerjesztett[:,1], label = "Euler")#3

xlabel('Idő [s]', fontsize = 20)
ylabel('Kitérét $[rad]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

savefig('gerj_xt.png')

# %%
figure(figsize = (15,10))
title("Gerjesztett-Csillapított inga kitérés-idő digramja", fontsize = 20)
plot(dat_ger_csill_rk[:,0],dat_ger_csill_rk[:,1], label = "Adaptiv Runge Kutta")#3
plot(dat_ger_csill_rk_sim[:,0],dat_ger_csill_rk_sim[:,1], label = "Runge Kutta")#3

plot(dat_EC_ger_csill[:,0],dat_EC_ger_csill[:,1], label = "Euler-Cromer")#3
plot(dat_E_ger_csill[:,0],dat_E_ger_csill[:,1], label = "Euler")#3

xlim(0,20)
xlabel('Idő [s]', fontsize = 20)
ylabel('Kitérét $[rad]$', fontsize = 20)
legend(loc='upper right',fontsize=15)
grid(True)

savefig('gerj_csill_xt.png')

# %%
figure(figsize = (15,10))
title("Matematikai inga sebesség-idő digramja", fontsize = 20)
plot(dat_math_rk[:,0],dat_math_rk[:,2], label = "Adaptiv Runge Kutta")#3
plot(dat_math_rk_sim[:,0],dat_math_rk_sim[:,2], label = "Runge Kutta")#3

plot(dat_E_mat[:,0],dat_E_mat[:,2], label = "Euler")#3
plot(dat_EC_mat[:,0],dat_EC_mat[:,2], label = "EulerCromer")

xlabel('Idő [s]', fontsize = 20)
ylabel('Sebesség $[1/s]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

savefig('mat_vt.png')

# %%
figure(figsize = (15,10))
title("Csillapított inga sebesség-idő digramja", fontsize = 20)
plot(dat_csill_rk[:,0],dat_csill_rk[:,2], label = "Adaptiv Runge Kutta")#3
plot(dat_csill_rk_sim[:,0],dat_csill_rk_sim[:,2], label = "Runge Kutta")#3

plot(dat_E_csill[:,0],dat_E_csill[:,2], label = "Euler")#3
plot(dat_EC_csill[:,0],dat_EC_csill[:,2], label = "Euler-Cromer")

xlim(0,30)
xlabel('Idő [s]', fontsize = 20)
ylabel('Sebesség $[1/s]$', fontsize = 20)
legend(loc='lower right',fontsize=15)
grid(True)

savefig('csill_vt.png')

# %%
figure(figsize = (15,10))
title("Gerjesztett inga sebesség-idő digramja", fontsize = 20)
plot(dat_ger_rk[:,0],dat_ger_rk[:,2], label = "Adaptiv Runge Kutta")#3
plot(dat_ger_rk_sim[:,0],dat_ger_rk_sim[:,2], label = "Runge Kutta")#3


plot(dat_EC_gerjesztett[:,0],dat_EC_gerjesztett[:,2], label = "Euler-Cromer")#3
plot(dat_E_gerjesztett[:,0],dat_E_gerjesztett[:,2], label = "Euler")#3

xlabel('Idő [s]', fontsize = 20)
ylabel('Sebesség $[1/s]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

savefig('gerj_vt.png')

# %%
figure(figsize = (15,10))
title("Gerjesztett-Csillapított inga sebesség-idő digramja", fontsize = 20)
plot(dat_ger_csill_rk[:,0],dat_ger_csill_rk[:,2], label = "Adaptiv Runge Kutta")#3
plot(dat_ger_csill_rk_sim[:,0],dat_ger_csill_rk_sim[:,2], label = "Runge Kutta")#3

plot(dat_EC_ger_csill[:,0],dat_EC_ger_csill[:,2], label = "Euler-Cromer")#3
plot(dat_E_ger_csill[:,0],dat_E_ger_csill[:,2], label = "Euler")#3

xlim(0,35)
xlabel('Idő [s]', fontsize = 20)
ylabel('Sebesség $[1/s]$', fontsize = 20)
legend(loc='lower right',fontsize=15)
grid(True)

savefig('gerj_csill_vt.png')

# %%
figure(figsize = (15,15))
title("Matematikai inga fázis digramja", fontsize = 20)
plot(dat_math_rk[:,1],dat_math_rk[:,2], label = "Adaptiv Runge Kutta")#3
plot(dat_math_rk_sim[:,1],dat_math_rk_sim[:,2], label = "Runge Kutta")#3

plot(dat_E_mat[:,1],dat_E_mat[:,2], label = "Euler")#3
plot(dat_EC_mat[:,1],dat_EC_mat[:,2], label = "EulerCromer")

xlabel('Kitérés $[rad]$', fontsize = 20)
ylabel('Szögsebesség $[1/s]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

savefig('mat_fazis.png')

# %%
figure(figsize = (15,15))
title("Csillapított inga fázis digramja", fontsize = 20)
plot(dat_csill_rk[:,1],dat_csill_rk[:,2], label = "Adaptiv Runge Kutta")#3
plot(dat_csill_rk_sim[:,1],dat_csill_rk_sim[:,2], label = "Runge Kutta")#3

plot(dat_E_csill[:,1],dat_E_csill[:,2], label = "Euler")#3
plot(dat_EC_csill[:,1],dat_EC_csill[:,2], label = "EulerCromer")

xlabel('Kitérés $[rad]$', fontsize = 20)
ylabel('Szögsebesség $[1/s]$', fontsize = 20)
legend(loc='upper right',fontsize=15)
grid(True)

savefig('csill_fazis.png')

# %%
figure(figsize = (15,15))
title("Gerjesztett inga fázis digramja", fontsize = 20)
plot(dat_ger_rk[:,1],dat_ger_rk[:,2], label = "Adaptiv Runge Kutta")#3
plot(dat_ger_rk_sim[:,1],dat_ger_rk_sim[:,2], label = "Runge Kutta")#3

plot(dat_EC_gerjesztett[:,1],dat_EC_gerjesztett[:,2], label = "Euler-Cromer")#3
plot(dat_E_gerjesztett[:,1],dat_E_gerjesztett[:,2], label = "Euler")#3

xlabel('Kitérés $[rad]$', fontsize = 20)
ylabel('Szögsebesség $[1/s]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

savefig('gerj_fazis.png')

# %%
figure(figsize = (15,15))
title("Gerjesztett-Csillapított inga fázis digramja", fontsize = 20)
plot(dat_ger_csill_rk[:,1],dat_ger_csill_rk[:,2], label = "Adaptiv Runge Kutta")#3
plot(dat_ger_csill_rk_sim[:,1],dat_ger_csill_rk_sim[:,2], label = "Runge Kutta")#3

plot(dat_EC_ger_csill[:,1],dat_EC_ger_csill[:,2], label = "Euler-Cromer")#3
plot(dat_E_ger_csill[:,1],dat_E_ger_csill[:,2], label = "Euler")#3

xlabel('Kitérés $[rad]$', fontsize = 20)
ylabel('Szögsebesség $[1/s]$', fontsize = 20)
legend(loc='upper right',fontsize=15)
grid(True)

savefig('gerj_csill_fazis.png')

# %%
figure(figsize = (15,10))
title("Matematikai inga energiája", fontsize = 20)
plot(dat_math_rk[:,0],dat_math_rk[:,3], label = "Adaptiv Runge Kutta")#3
plot(dat_math_rk_sim[:,0],dat_math_rk_sim[:,3], label = "Runge Kutta")#3

xlabel('Idő $[s]$', fontsize = 20)
ylabel('Energia $[J]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
#xlim(0,20)
#axhline(y=0, color = 'b')
grid(True)

savefig('mat_e_rk.png')

# %%
ark = max(dat_math_rk[:,3])-min(dat_math_rk[:,3])
rk = max(dat_math_rk_sim[:,3])-min(dat_math_rk_sim[:,3])
print(ark)
print(rk)
# Out:
# 0.007829999999999782
# 0.007829999999999782

# %%
figure(figsize = (15,10))
title("Matematikai inga energiája", fontsize = 20)

plot(dat_E_mat[:,0],dat_E_mat[:,3], label = "Euler")#3

xlabel('Idő $[s]$', fontsize = 20)
ylabel('Energia $[J]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
#xlim(0,20)
#axhline(y=0, color = 'b')
grid(True)

savefig('mat_e_eu.png')

# %%
figure(figsize = (15,10))
title("Matematikai inga energiája", fontsize = 20)
plot(dat_EC_mat[:,0],dat_EC_mat[:,3], label = "EulerCromer")

xlabel('Idő $[s]$', fontsize = 20)
ylabel('Energia $[J]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
grid(True)

savefig('mat_e_eu_c.png')

# %%
figure(figsize = (15,10))
title("Csillapított inga energiája", fontsize = 20)
plot(dat_csill_rk[:,0],dat_csill_rk[:,3], label = "Adaptiv Runge Kutta")#3
plot(dat_csill_rk_sim[:,0],dat_csill_rk_sim[:,3], label = "Runge Kutta")#3

plot(dat_E_csill[:,0],dat_E_csill[:,3], label = "Euler")#3
plot(dat_EC_csill[:,0],dat_EC_csill[:,3], label = "EulerCromer")

xlabel('Idő $[s]$', fontsize = 20)
ylabel('Energia $[J]$', fontsize = 20)
legend(loc='upper right',fontsize=15)
xlim(0,20)
#axhline(y=0, color = 'b')
grid(True)

savefig('csill_e.png')

# %%
figure(figsize = (15,10))
title("Gerjesztett inga energia", fontsize = 20)

plot(dat_EC_gerjesztett[:,0],dat_EC_gerjesztett[:,3], label = "Euler-Cromer")#3
plot(dat_E_gerjesztett[:,0],dat_E_gerjesztett[:,3], label = "Euler")#3

plot(dat_ger_rk[:,0],dat_ger_rk[:,3], label = "Adaptiv Runge Kutte")#3
plot(dat_ger_rk_sim[:,0],dat_ger_rk_sim[:,3], label = "Runge Kutte")#3

xlabel('Idő $[s]$', fontsize = 20)
ylabel('Energia $[J]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
#xlim(0,30)
#axhline(y=0, color = 'b')
grid(True)

savefig('gerj_e.png')

# %%
#MÁS

figure(figsize = (15,10))
title("Gerjesztett inga energia", fontsize = 20)
plot(dat[:,0],dat[:,3], label = "Euler")#3

xlabel('Idő $[s]$', fontsize = 20)
ylabel('Energia $[J]$', fontsize = 20)

#xlim(0,30)
slope, intercept, r_value, p_value, std_err =linregress(dat[:,0], dat[:,3])
x = linspace(0,300,300)

plot(x,slope*x+intercept, label ="Illesztette egyenes. Meredekség = 1.5, Tengelymetszet = 10.3.89 ")
legend(loc='upper left',fontsize=15)

savefig('gerj_lin.png')

# %%
figure(figsize = (15,10))
title("Gerjesztett-Csillapított inga energia", fontsize = 20)
plot(dat_ger_csill_rk[:,0],dat_ger_csill_rk[:,3], label = "Adaptiv Runge Kutta")#3
plot(dat_ger_csill_rk_sim[:,0],dat_ger_csill_rk_sim[:,3], label = "Runge Kutta")#3

plot(dat_EC_ger_csill[:,0],dat_EC_ger_csill[:,3], label = "Euler-Cromer")#3
plot(dat_E_ger_csill[:,0],dat_E_ger_csill[:,3], label = "Euler")#3

xlabel('Idő $[s]$', fontsize = 20)
ylabel('Energia $[J]$', fontsize = 20)
legend(loc='upper left',fontsize=15)
xlim(0,30)
#axhline(y=0, color = 'b')
grid(True)

savefig('gerj_csill_e.png')
