# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_md = loadtxt('T.data')
shape(data_md)
# Out:
# (30000,)

# %%
plot(data_md)

# %%
x_md1 = linspace(0,300,30000)
figure(figsize=(15,8))
plot(x_md1,data_md,'.',markersize = 0.5)
legend(fontsize=23)
xlabel("időegység (lépés$\cdot 0.01$)", fontsize=23)
ylabel("T", fontsize=23)
title("A pillanatnyi hőmérséklet időfüggése, md.cpp", fontsize=23)
#xticks(arange(0, 51, 300)) 
grid(True)
savefig("md.png")
# Out:
# No handles with labels found to put in legend.

# %%
data_md2 = loadtxt('T2.data')
shape(data_md2)
# Out:
# (30000,)

# %%
plot(data_md2)

# %%
x_md2 = linspace(0,300,30000)
figure(figsize=(15,8))
plot(x_md2,data_md2,'.',markersize = 1)
legend(fontsize=23)
xlabel("időegység (lépés$\cdot 0.01$)", fontsize=23)
ylabel("T", fontsize=23)
title("A pillanatnyi hőmérséklet időfüggése, md2.cpp", fontsize=23)
#xticks(arange(0, 2000, 150)) 
xlim(-1,45)
grid(True)
savefig("md2.png")
# Out:
# No handles with labels found to put in legend.

# %%
data_md3 = loadtxt('T3_rc3rm33.data')
data_md4 = loadtxt('T3_rc1rm33.data')
data_md5 = loadtxt('T3_rc15rm33.data')
data_md6 = loadtxt('T3_rc2rm33.data')
data_md7 = loadtxt('T3_rc25rm33.data')
data_md8 = loadtxt('T3_rc6rm33.data')
shape(data_md3)
# Out:
# (3000,)

# %%
plot(data_md6)

# %%
x_md3 = linspace(0,30,3000)
figure(figsize=(15,10))
#plot(data_md3,'.',markersize = 1)
plot(x_md3,data_md4,'-',markersize = 1,label = 'Rcutoff = 1')
plot(x_md3,data_md5,'-',markersize = 1,label = 'Rcutoff = 1.5')
plot(x_md3,data_md6,'-',markersize = 1,label = 'Rcutoff = 2')
plot(x_md3,data_md7,'-',markersize = 1,label = 'Rcutoff = 2.5')
plot(x_md3,data_md3,'-',markersize = 1,label = 'Rcutoff = 3')
plot(x_md3,data_md8,'-',markersize = 1,label = 'Rcutoff = 6')
legend(fontsize=23)
xlabel("időegység (lépés$\cdot 0.01$)", fontsize=23)
ylabel("T", fontsize=23)
title("A pillanatnyi hőmérséklet időfüggése, md3.cpp", fontsize=23)
#xticks(arange(0, 2000, 150)) 
#xlim(-1,45)
grid(True)
savefig("md3rc.png")

# %%
data_md9 = loadtxt('T3_rc25rm33.data')
data_md10 = loadtxt('T3_rc25rm3.data')
data_md11 = loadtxt('T3_rc25rm25.data')
data_md12 = loadtxt('T3_rc25rm2.data')
data_md13= loadtxt('T3_rc25rm15.data')
data_md14 = loadtxt('T3_rc25rm1.data')
shape(data_md9)
# Out:
# (3000,)

# %%
x_md3 = linspace(0,30,3000)
figure(figsize=(15,10))
#plot(data_md3,'.',markersize = 1)
#plot(x_md3,data_md9,'.',markersize = 1,label = 'Rmax = 3.3')
#plot(x_md3,data_md10,'.',markersize = 1,label = 'Rmax = 3')
#plot(x_md3,data_md11,'.',markersize = 1,label = 'Rmax = 2.5')
#plot(x_md3,data_md12,'.',markersize = 1,label = 'Rmax = 2')
#plot(x_md3,data_md13,'.',markersize = 1,label = 'Rmax = 1.5')
plot(x_md3,data_md14,'.',markersize = 1,label = 'Rmax = 1')
legend(fontsize=23)
xlabel("időegység (lépés$\cdot 0.01$)", fontsize=23)
ylabel("T", fontsize=23)
title("A pillanatnyi hőmérséklet időfüggése, md3.cpp", fontsize=23)
#xticks(arange(0, 2000, 150)) 
#xlim(-1,45)
grid(True)
savefig("md3rm1.png")

# %%
data_md15 = loadtxt('Tup5.data')
data_md16 = loadtxt('Tup10.data')
data_md17 = loadtxt('Tup15.data')
data_md18 = loadtxt('Tup25.data')
data_md19 = loadtxt('Tup1.data')
shape(data_md15)
# Out:
# (10000,)

# %%
x_md3 = linspace(0,100,10000)
figure(figsize=(15,10))
#plot(data_md3,'.',markersize = 1)
plot(data_md19,'-',markersize = 1,label = 'Updateinterval = 1')
plot(data_md15,'-',markersize = 1,label = 'Updateinterval = 5')
plot(data_md16,'-',markersize = 1,label = 'Updateinterval = 10')
plot(data_md17,'-',markersize = 1,label = 'Updateinterval = 15')
plot(data_md18,'-',markersize = 1,label = 'Updateinterval = 25')
legend(fontsize=23)
xlabel("időegység (lépés$\cdot 0.01$)", fontsize=23)
ylabel("T", fontsize=23)
title("A pillanatnyi hőmérséklet időfüggése, md3.cpp", fontsize=23)
#xticks(arange(0, 2000, 150)) 
#xlim(-1,45)
grid(True)
savefig("md3Tup.png")

# %%
data_mdm = loadtxt('T3mind.data')
shape(data_mdm)#E,CV,P*V,Z(kompresszibilitás)
# Out:
# (10000, 5)

# %%
x_md4 = linspace(0,100,10000)
figure(figsize=(15,10))
plot(x_md4,data_mdm[:,4],'-',markersize = 1)
legend(fontsize=23)
xlabel("időegység (lépés$\cdot 0.01$)", fontsize=23)
ylabel("Z", fontsize=23)
title("A pillanatnyi kompresszibilitás időfüggése, md3.cpp", fontsize=23)
#xticks(arange(0, 2000, 150)) 
#xlim(-1,45)
grid(True)
#savefig("md3Z.png")
# Out:
# No handles with labels found to put in legend.
